# %% [markdown]
# <a href="https://colab.research.google.com/github/Somtochukwu-Achikanu/Machine-learning-handson/blob/main/Regression_to_mean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.formula.api import ols

# %%
sp500 = pd.read_csv('/content/sp500_yearly_returns.csv')
print(sp500.head())
# Out:
#   symbol  return_2018  return_2019
# 0   AAPL    -0.053902     0.889578
# 1   MSFT     0.207953     0.575581
# 2   AMZN     0.284317     0.230278
# 3     FB    -0.257112     0.565718
# 4  GOOGL    -0.008012     0.281762

# %%
fig = plt.figure()

# Plot the first layer: y = x
plt.axline(xy1=(0,0), slope=1, linewidth=2, color="red")

#scatter plot with linear regression trend line
sns.regplot(x ='return_2018',y='return_2019', data=sp500,ci=None)

# Set the axes so that the distances along the x and y axes look the same
plt.axis('equal')

# Show the plot
plt.show()

# %%
#Run a linear regression on return_2019 versus return_2018 using sp500_yearly_returns and fit the model. Assign to mdl_returns.
#Print the parameters of the model.

mdl_returns = ols('return_2019 ~ return_2018', data=sp500).fit()
print(mdl_returns.params)
# Out:
# Intercept      0.321321
# return_2018    0.020069
# dtype: float64

# %%
#Create a DataFrame named explanatory_data. Give it one column (return_2018) with 2018 returns set to a list containing -1, 0, and 1.
#Use mdl_returns to predict with explanatory_data in a print() call.

explanatory_data =pd.DataFrame({'return_2018': [-1,0,1]})
predict = mdl_returns.predict(explanatory_data)
print(predict)
# Out:
# 0    0.301251
# 1    0.321321
# 2    0.341390
# dtype: float64
